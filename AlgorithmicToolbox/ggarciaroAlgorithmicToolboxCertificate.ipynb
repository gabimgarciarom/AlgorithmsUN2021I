# %% [markdown]
# #Certificado Coursera#
# [LinkedIn](https://www.linkedin.com/in/gabriela-garc%C3%ADa-romero-20aa8baa)

# %% [markdown]
# ![Captura.PNG](data:image/png;base64,...)

# %% [markdown]
# ![CERTIFICATE_LANDING_PAGE_4MUREBAY5DE8.jpeg](data:image/jpeg;base64,...)
